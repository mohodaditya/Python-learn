# %% [markdown]
# ## learing for loop in py

# %%
# this code prints every charector from the string 

str = "Aditya Mohod"

for i in str:
    print(i)
# Out:
# A
# d
# i
# t
# y
# a
#
# M
# o
# h
# o
# d

# %%
# this code prints the count of charetor 'g' in the fllowing string 

str = "Programming"
count = 0

for i in str:
    if i == 'g':
        count += 1
print(count)
# Out:
# 2

# %%
# this code # this code prints the frequency of charetor in the fllowing string while taking string and charector as an input

str = input("Enter your string : ")
char = input("enter your char : ")
count = 0

for i in str:
    if i == char:
        count += 1
print(" frequency of ", char , " in ", str, " : ", count)
# Out:
#  frequency of  m  in  mohod  :  1

# %%
# this will count the frequence of white-spaces in the user input given string 

count =0
s = input("Enter str ")
for i in s :
    if i  == " ":
        count += 1

print(s)
print("total space are :" , count)
# Out:
# i love to do coding in python using vs code
# total space are : 10

# %%
# this code is checks for the is the strig is a palendrom or not while taking strig as an input from the user 
count =0
s = input("enter string : ")

p = s[ : : -1]

for i in s :
    if s  == p:
        print("string is a palandrom")
    else:
        print("string is not a palandrom")
# Out:
# string is a palandrom
# string is a palandrom
# string is a palandrom
# string is a palandrom
# string is a palandrom
